# %%
df = pd.read_csv('gym_members_exercise_tracking.csv')

# %%
# import pandas as pd

# # 데이터 로드
# df = pd.read_csv("gym_members_exercise_tracking.csv")

# # 칼럼 이름 변경
# df.columns = [
#     'age', 
#     'gender', 
#     'weight', 
#     'height', 
#     'max_bpm', 
#     'avg_bpm', 
#     'resting_bpm', 
#     'duration', 
#     'calory', 
#     'workout_type', 
#     'fat_percentage', 
#     'water', 
#     'workout_frequency', 
#     'experience_level', 
#     'bmi'
# ]

# # 변경된 DataFrame을 CSV 파일로 저장
# df.to_csv("gyms.csv", index=False)

# %%
df = pd.read_csv("gyms.csv")
df
# Out:
#      age  gender  weight  height  max_bpm  avg_bpm  resting_bpm  duration  \
# 0     56    Male    88.3    1.71      180      157           60      1.69
# 1     46  Female    74.9    1.53      179      151           66      1.30
# 2     32  Female    68.1    1.66      167      122           54      1.11
# 3     25    Male    53.2    1.70      190      164           56      0.59
# 4     38    Male    46.1    1.79      188      158           68      0.64
# ..   ...     ...     ...     ...      ...      ...          ...       ...
# 968   24    Male    87.1    1.74      187      158           67      1.57
# 969   25    Male    66.6    1.61      184      166           56      1.38
# 970   59  Female    60.4    1.76      194      120           53      1.72
# 971   32    Male   126.4    1.83      198      146           62      1.10
# 972   46    Male    88.7    1.63      166      146           66      0.75
#
#      calory workout_type  fat_percentage  water  workout_frequency  \
# 0    1313.0         Yoga            12.6    3.5                  4
# 1     883.0         HIIT            33.9    2.1                  4
# 2     677.0       Cardio            33.4    2.3                  4
# 3     532.0     Strength            28.8    2.1                  3
# 4     556.0     Strength            29.2    2.8                  3
# ..      ...          ...             ...    ...                ...
# 968  1364.0     Strength            10.0    3.5                  4
# 969  1260.0     Strength            25.0    3.0                  2
# 970   929.0       Cardio            18.8    2.7                  5
# 971   883.0         HIIT            28.2    2.1                  3
# 972   542.0     Strength            28.8    3.5                  2
#
#      experience_level    bmi
# 0                   3  30.20
# 1                   2  32.00
# 2                   2  24.71
# 3                   1  18.41
# 4                   1  14.39
# ..                ...    ...
# 968                 3  28.77
# 969                 1  25.69
# 970                 3  19.50
# 971                 2  37.74
# 972                 1  33.38
#
# [973 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# age                  0
# gender               0
# weight               0
# height               0
# max_bpm              0
# avg_bpm              0
# resting_bpm          0
# duration             0
# calory               0
# workout_type         0
# fat_percentage       0
# water                0
# workout_frequency    0
# experience_level     0
# bmi                  0
# dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for col in df.columns:
#       2     print(df[col].value_counts())
#
# NameError: name 'df' is not defined
