# %%
import pandas as pd
df = pd.read_csv('gyms.csv')

# %%
df
# Out:
#      age  gender  weight  height  max_bpm  avg_bpm  resting_bpm  duration  \
# 0     56    Male    88.3    1.71      180      157           60      1.69
# 1     46  Female    74.9    1.53      179      151           66      1.30
# 2     32  Female    68.1    1.66      167      122           54      1.11
# 3     25    Male    53.2    1.70      190      164           56      0.59
# 4     38    Male    46.1    1.79      188      158           68      0.64
# ..   ...     ...     ...     ...      ...      ...          ...       ...
# 968   24    Male    87.1    1.74      187      158           67      1.57
# 969   25    Male    66.6    1.61      184      166           56      1.38
# 970   59  Female    60.4    1.76      194      120           53      1.72
# 971   32    Male   126.4    1.83      198      146           62      1.10
# 972   46    Male    88.7    1.63      166      146           66      0.75
#
#      calory workout_type  fat_percentage  water  workout_frequency  \
# ...

# %%
for col in df.columns:
    print(df[col].value_counts(), "\n")
# Out:
# age
# 43    34
# 50    33
# 52    32
# 45    30
# 54    30
# 22    27
# 18    27
# 42    27
# 56    27
# 49    26
# 25    26
# 19    26
# 41    26
# 40    25
# 20    25
# 23    25
# 34    24
# 31    24
# 57    23
# 53    23
# 39    23
# 28    23
# 47    23
# 29    23
# 26    21
# 36    21
# 33    21
# 32    21
# 46    21
# 38    20
# 21    20
# 37    19
# 51    19
# 58    19
# 30    19
# 59    19
# 55    18
# 27    18
# 35    17
# 48    17
# 44    16
# 24    15
# Name: count, dtype: int64
#
# gender
# Male      511
# Female    462
# Name: count, dtype: int64
#
# weight
# 57.7     6
# 75.6     6
# 64.3     5
# 50.3     5
# 81.4     5
#         ..
# 107.0    1
# 105.3    1
# 95.2     1
# 113.6    1
# 88.7     1
# Name: count, Length: 532, dtype: int64
#
# height
# 1.62    44
# 1.76    37
# 1.77    37
# 1.61    36
# 1.79    32
# 1.68    31
# 1.71    30
# 1.63    29
# 1.72    28
# 1.60    27
# 1.74    27
# 1.67    26
# 1.69    26
# 1.75    26
# 1.66    25
# 1.65    24
# 1.64    22
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'weight', 'height', 'max_bpm', 'avg_bpm',
#        'resting_bpm', 'duration', 'calory', 'workout_type', 'fat_percentage',
#        'water', 'workout_frequency', 'experience_level', 'bmi'],
#       dtype='object')
